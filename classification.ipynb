# %%
import pandas
data = pandas.read_csv("datasets/recipe.csv")
data
# Out:
#     Flour  Milk  Sugar  Butter  Egg  Baking Powder  Vanilla  Salt     Type
# 0      55    28      3       7    5              2        0     0   Muffin
# 1      47    24     12       6    9              1        0     0   Muffin
# 2      47    23     18       6    4              1        0     0   Muffin
# 3      45    11     17      17    8              1        0     0   Muffin
# 4      50    25     12       6    5              2        1     0   Muffin
# 5      55    27      3       7    5              2        1     0   Muffin
# 6      54    27      7       5    5              2        0     0   Muffin
# 7      47    26     10      10    4              1        0     0   Muffin
# 8      50    17     17       8    6              1        0     0   Muffin
# 9      50    17     17      11    4              1        0     0   Muffin
# 10     39     0     26      19   14              1        1     0  Cupcake
# ...

# %%
data.describe()
# Out:
#            Flour       Milk      Sugar     Butter        Egg  Baking Powder  \
# count  50.000000  50.000000  50.000000  50.000000  50.000000      50.000000
# mean   39.340000  15.920000  23.080000   9.740000   6.940000       2.680000
# std    11.213348   8.090912  14.037617   4.898188   3.644453       3.152194
# min    19.000000   0.000000   3.000000   3.000000   0.000000       0.000000
# 25%    34.000000  11.000000  16.000000   6.000000   5.000000       1.000000
# 50%    39.000000  17.000000  20.000000   8.000000   6.000000       1.000000
# 75%    47.750000  23.000000  26.000000  12.000000   9.000000       2.000000
# max    55.000000  28.000000  52.000000  20.000000  14.000000      11.000000
#
#          Vanilla       Salt
# count  50.000000  50.000000
# mean    0.960000   0.960000
# std     2.732719   1.989359
# min     0.000000   0.000000
# 25%     0.000000   0.000000
# 50%     0.000000   0.000000
# 75%     1.000000   0.000000
# max    14.000000   6.000000

# %%
# separate the ingredients from the outcome
array = data.values
#X shall represent the training data => inputs/features/labels
# Y shall represent the outcome => prediction
X = array[:, 0:10]

Y= array[:,8]

# %%
# split the data even further 

from sklearn import model_selection

X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.fit(X_train,Y_train)
#
# NameError: name 'model' is not defined

# %%
# test the model to see what it will predict
predictions = model.predict(X_test)

print("Model predicted: ", predictions)
print("We expected: ", Y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 # test the model to see what it will predict
# ----> 2 predictions = model.predict(X_test)
#       3
#       4 print("Model predicted: ", predictions)
#       5 print("We expected: ", Y_test)
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\svm\_base.py:817, in BaseSVC.predict(self, X)
#     800 def predict(self, X):
#     801     """Perform classification on samples in X.
#     802
#     803     For a one-class model, +1 or -1 is returned.
#    (...)    815         Class labels for samples in X.
#     816     """
# --> 817     check_is_fitted(self)
#     818     if self.break_ties and self.decision_function_shape == "ovo":
#     819         raise ValueError(
#     820             "break_ties must be False when decision_function_shape is 'ovo'"
# ...

# %%
# Test the accuracy score of the model
from sklearn.metrics import accuracy_score
print("Accuracy: ", accuracy_score(Y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Test the accuracy score of the model
#       2 from sklearn.metrics import accuracy_score
# ----> 3 print("Accuracy: ", accuracy_score(Y_test, predictions))
#
# NameError: name 'predictions' is not defined

# %%
recipe =[ [10,7,8,1,4,1,6,3]]
outcome = model.predict(recipe)
print("You will be cooking a ",outcome)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[20], line 2
#       1 recipe =[ [10,7,8,1,4,1,6,3]]
# ----> 2 outcome = model.predict(recipe)
#       3 print("You will be cooking a ",outcome)
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\svm\_base.py:817, in BaseSVC.predict(self, X)
#     800 def predict(self, X):
#     801     """Perform classification on samples in X.
#     802
#     803     For a one-class model, +1 or -1 is returned.
#    (...)    815         Class labels for samples in X.
#     816     """
# --> 817     check_is_fitted(self)
#     818     if self.break_ties and self.decision_function_shape == "ovo":
#     819         raise ValueError(
#     820             "break_ties must be False when decision_function_shape is 'ovo'"
#     821         )
#
# ...

# %%
# Imports Classification Models
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC

# Create an Empty List and append all models, Give the Models an alias Name
# i.e we called KNeighborsClassifier() alias KNC etc
models = []
models.append(('D Trees', DecisionTreeClassifier()))
models.append(('Gaussian', GaussianNB()))
models.append(('KNC', KNeighborsClassifier()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('Gradient Boosting', GradientBoostingClassifier()))
models.append(('Linear Disc', LinearDiscriminantAnalysis()))
models.append(('Support Machines', SVC(gamma = 'auto')))

# Import Cross Validation and KFOLD
from sklearn.model_selection import cross_val_score, KFold
# Create a for loop so that each model is tested in turn
for name, model in models:
            # Here we do a 10 split K-FOLD - We split our data into 10 Folds
            kfold = KFold(n_splits = 10, random_state=42, shuffle=True)

            # We Train and Test the current model in the Loop
            # Get the results for each Fold
            cv_results = cross_val_score(model, X_train, Y_train, cv = kfold,
            scoring='accuracy')

            # Get the average of all Folds For that specific model in the Loop
            print(name, ' Results:= ', cv_results.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 31
#      27             kfold = KFold(n_splits = 10, random_state=42, shuffle=True)
#      28
#      29             # We Train and Test the current model in the Loop
#      30             # Get the results for each Fold
# ---> 31             cv_results = cross_val_score(model, X_train, Y_train, cv = kfold,
#      32             scoring='accuracy')
#      33
#      34             # Get the average of all Folds For that specific model in the Loop
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
# ...
